# %% [markdown]
# # Creating the ML Model for CMU’s admission system

# %% [markdown]
# ## Load the data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('data/student-mat.csv', sep=';')
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %% [markdown]
# ## Preprocess the data
# ### Remove unneeded attributes

# %%
# We chose to remove all attributtes not relevant to the CMU setting.
# `school` is specific to the source data set, and the grades are also
# not relevant (we keep the last grade to know the expected prediction value)
df.drop(columns=['school', 'G1', 'G2'], inplace=True)
df
# Out:
#     sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  reason  \
# 0     F   18       U     GT3       A     4     4   at_home   teacher  course
# 1     F   17       U     GT3       T     1     1   at_home     other  course
# 2     F   15       U     LE3       T     1     1   at_home     other   other
# 3     F   15       U     GT3       T     4     2    health  services    home
# 4     F   16       U     GT3       T     3     3     other     other    home
# ..   ..  ...     ...     ...     ...   ...   ...       ...       ...     ...
# 390   M   20       U     LE3       A     2     2  services  services  course
# 391   M   17       U     LE3       T     3     1  services  services  course
# 392   M   21       R     GT3       T     1     1     other     other  course
# 393   M   18       R     LE3       T     3     2  services     other  course
# 394   M   19       U     LE3       T     1     1     other   at_home  course
#
#      ... internet  romantic  famrel  freetime goout Dalc Walc health absences  \
# 0    ...       no        no       4         3     4    1    1      3        6
# 1    ...      yes        no       5         3     3    1    1      3        4
# 2    ...      yes        no       4         3     2    2    3      3       10
# 3    ...      yes       yes       3         2     2    1    1      5        2
# 4    ...       no        no       4         3     2    1    2      5        4
# ..   ...      ...       ...     ...       ...   ...  ...  ...    ...      ...
# 390  ...       no        no       5         5     4    4    5      4       11
# 391  ...      yes        no       2         4     5    3    4      2        3
# 392  ...       no        no       5         5     3    3    3      3        3
# 393  ...      yes        no       4         4     1    3    4      5        0
# 394  ...      yes        no       3         2     3    3    3      5        5
#
#      G3
# 0     6
# 1     6
# 2    10
# 3    15
# 4    10
# ..   ..
# 390   9
# 391  16
# 392   7
# 393  10
# 394   9
#
# [395 rows x 30 columns]

# %% [markdown]
# ### Convert binary attributes to numerical attributes

# %%
df['sex'] = np.where(df['sex'] == 'F', 1, 0)
df['address'] = np.where(df['address'] == 'U', 1, 0)
df['famsize'] = np.where(df['famsize'] == 'LE3', 1, 0)
df['Pstatus'] = np.where(df['Pstatus'] == 'T', 1, 0)

for binary_attribute in ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    df[binary_attribute] = np.where(df[binary_attribute] == 'yes', 1, 0)

df
# Out:
#      sex  age  address  famsize  Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      1   18        1        0        0     4     4   at_home   teacher
# 1      1   17        1        0        1     1     1   at_home     other
# 2      1   15        1        1        1     1     1   at_home     other
# 3      1   15        1        0        1     4     2    health  services
# 4      1   16        1        0        1     3     3     other     other
# ..   ...  ...      ...      ...      ...   ...   ...       ...       ...
# 390    0   20        1        1        0     2     2  services  services
# 391    0   17        1        1        1     3     1  services  services
# 392    0   21        0        0        1     1     1     other     other
# 393    0   18        0        1        1     3     2  services     other
# 394    0   19        1        1        1     1     1     other   at_home
#
#      reason  ... internet  romantic  famrel  freetime  goout  Dalc  Walc  \
# 0    course  ...        0         0       4         3      4     1     1
# 1    course  ...        1         0       5         3      3     1     1
# 2     other  ...        1         0       4         3      2     2     3
# 3      home  ...        1         1       3         2      2     1     1
# 4      home  ...        0         0       4         3      2     1     2
# ..      ...  ...      ...       ...     ...       ...    ...   ...   ...
# 390  course  ...        0         0       5         5      4     4     5
# 391  course  ...        1         0       2         4      5     3     4
# 392  course  ...        0         0       5         5      3     3     3
# 393  course  ...        1         0       4         4      1     3     4
# 394  course  ...        1         0       3         2      3     3     3
#
#      health  absences  G3
# 0         3         6   6
# 1         3         4   6
# 2         3        10  10
# 3         5         2  15
# 4         5         4  10
# ..      ...       ...  ..
# 390       4        11   9
# 391       2         3  16
# 392       3         3   7
# 393       5         0  10
# 394       5         5   9
#
# [395 rows x 30 columns]

# %% [markdown]
# ### Convert nominal attributes to numerical attributes

# %%
categories = {
    'Mjob': ['teacher', 'health', 'services', 'at_home', 'other'],
    'Fjob': ['teacher', 'health', 'services', 'at_home', 'other'],
    'reason': ['home', 'reputation', 'course', 'other'],
    'guardian': ['mother', 'father', 'other'],
}

for category in categories:
    values = categories[category]
    df[category] = df[category].map(values.index)

df
# Out:
#      sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  ...  \
# 0      1   18        1        0        0     4     4     3     0       2  ...
# 1      1   17        1        0        1     1     1     3     4       2  ...
# 2      1   15        1        1        1     1     1     3     4       3  ...
# 3      1   15        1        0        1     4     2     1     2       0  ...
# 4      1   16        1        0        1     3     3     4     4       0  ...
# ..   ...  ...      ...      ...      ...   ...   ...   ...   ...     ...  ...
# 390    0   20        1        1        0     2     2     2     2       2  ...
# 391    0   17        1        1        1     3     1     2     2       2  ...
# 392    0   21        0        0        1     1     1     4     4       2  ...
# 393    0   18        0        1        1     3     2     2     4       2  ...
# 394    0   19        1        1        1     1     1     4     3       2  ...
#
#      internet  romantic  famrel  freetime  goout  Dalc  Walc  health  \
# 0           0         0       4         3      4     1     1       3
# 1           1         0       5         3      3     1     1       3
# 2           1         0       4         3      2     2     3       3
# 3           1         1       3         2      2     1     1       5
# 4           0         0       4         3      2     1     2       5
# ..        ...       ...     ...       ...    ...   ...   ...     ...
# 390         0         0       5         5      4     4     5       4
# 391         1         0       2         4      5     3     4       2
# 392         0         0       5         5      3     3     3       3
# 393         1         0       4         4      1     3     4       5
# 394         1         0       3         2      3     3     3       5
#
#      absences  G3
# 0           6   6
# 1           4   6
# 2          10  10
# 3           2  15
# 4           4  10
# ..        ...  ..
# 390        11   9
# 391         3  16
# 392         3   7
# 393         0  10
# 394         5   9
#
# [395 rows x 30 columns]

# %% [markdown]
# ### Create the prediction column

# %%
df['qual_student'] = np.where(df['G3'] >= 15, 1, 0)
df.drop(columns=['G3'], inplace=True)

df
# Out:
#      sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  ...  \
# 0      1   18        1        0        0     4     4     3     0       2  ...
# 1      1   17        1        0        1     1     1     3     4       2  ...
# 2      1   15        1        1        1     1     1     3     4       3  ...
# 3      1   15        1        0        1     4     2     1     2       0  ...
# 4      1   16        1        0        1     3     3     4     4       0  ...
# ..   ...  ...      ...      ...      ...   ...   ...   ...   ...     ...  ...
# 390    0   20        1        1        0     2     2     2     2       2  ...
# 391    0   17        1        1        1     3     1     2     2       2  ...
# 392    0   21        0        0        1     1     1     4     4       2  ...
# 393    0   18        0        1        1     3     2     2     4       2  ...
# 394    0   19        1        1        1     1     1     4     3       2  ...
#
#      internet  romantic  famrel  freetime  goout  Dalc  Walc  health  \
# 0           0         0       4         3      4     1     1       3
# 1           1         0       5         3      3     1     1       3
# 2           1         0       4         3      2     2     3       3
# 3           1         1       3         2      2     1     1       5
# 4           0         0       4         3      2     1     2       5
# ..        ...       ...     ...       ...    ...   ...   ...     ...
# 390         0         0       5         5      4     4     5       4
# 391         1         0       2         4      5     3     4       2
# 392         0         0       5         5      3     3     3       3
# 393         1         0       4         4      1     3     4       5
# 394         1         0       3         2      3     3     3       5
#
#      absences  qual_student
# 0           6             0
# 1           4             0
# 2          10             0
# 3           2             1
# 4           4             0
# ..        ...           ...
# 390        11             0
# 391         3             1
# 392         3             0
# 393         0             0
# 394         5             0
#
# [395 rows x 30 columns]

# %% [markdown]
# ## Training the model
# ### Create train/test sets

# %%
import sklearn
import sklearn.model_selection

dependent_variable = 'qual_student'
x = df[df.columns.difference([dependent_variable])]
y = df[dependent_variable]

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, random_state=1)

# %%
import autosklearn.classification
import sklearn.datasets
import sklearn.metrics

# Total time spent on training models
total_time_sec = 60 * 60

# Maximum time for some model
time_per_job_sec = 30

# Number of parallel jobs
n_jobs = 7

automl = autosklearn.classification.AutoSklearnClassifier(time_left_for_this_task=total_time_sec, per_run_time_limit=time_per_job_sec, n_jobs=n_jobs)
automl.fit(X_train, y_train)
# Out:
# [WARNING] [2022-11-06 17:28:49,740:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:28:50,382:Client-EnsembleBuilder] No runs were available to build an ensemble from
# [WARNING] [2022-11-06 17:28:56,142:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:28:58,929:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:29:03,275:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:29:07,653:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:29:10,676:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:29:12,131:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# [WARNING] [2022-11-06 17:29:13,584:Client-EnsembleBuilder] No models better than random - using Dummy losses!
# 	Models besides current dummy model: 0
# 	Dummy models: 1
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       n_jobs=7, per_run_time_limit=30)

# %% [markdown]
# ## Test the model accuracy

# %%
print(automl.leaderboard())
# Out:
#           rank  ensemble_weight           type      cost   duration
# model_id
# 54           1             0.42  decision_tree  0.183673   5.269463
# 181          2             0.02            mlp  0.183673   6.047660
# 10           3             0.28            mlp  0.193878  25.193798
# 26           4             0.10  random_forest  0.193878  15.498308
# 105          5             0.04            mlp  0.193878  18.993294
# 164          6             0.12            mlp  0.193878  17.878329
# 178          7             0.02  liblinear_svc  0.193878   5.784644

# %%
print(automl.show_models())
# Out:
# {10: {'model_id': 10, 'rank': 1, 'cost': 0.19387755102040816, 'ensemble_weight': 0.28, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x4170e5c370>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x41b1a9c460>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x4133429fd0>, 'sklearn_classifier': MLPClassifier(activation='tanh', alpha=0.0001363185819149026, beta_1=0.999,
#               beta_2=0.9, early_stopping=True,
#               hidden_layer_sizes=(115, 115, 115),
#               learning_rate_init=0.00018009776276177523, max_iter=64,
#               n_iter_no_change=32, random_state=1, verbose=0, warm_start=True)}, 26: {'model_id': 26, 'rank': 2, 'cost': 0.19387755102040816, 'ensemble_weight': 0.1, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x415672ca30>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x4167b151f0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x4167b153a0>, 'sklearn_classifier': RandomForestClassifier(bootstrap=False, max_features=5, min_samples_leaf=4,
#                        min_samples_split=20, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)}, 54: {'model_id': 54, 'rank': 3, 'cost': 0.18367346938775508, 'ensemble_weight': 0.42, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x41c3cb8af0>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x41b10e6070>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x41b1e3dd90>, 'sklearn_classifier': DecisionTreeClassifier(criterion='entropy', max_depth=29, min_samples_leaf=19,
#                        min_samples_split=9, random_state=1)}, 105: {'model_id': 105, 'rank': 4, 'cost': 0.19387755102040816, 'ensemble_weight': 0.04, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x4129e600d0>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x417036bd30>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x417036b4f0>, 'sklearn_classifier': MLPClassifier(alpha=5.6887157296879365e-05, beta_1=0.999, beta_2=0.9,
#               early_stopping=True, hidden_layer_sizes=(155, 155, 155),
#               learning_rate_init=0.00026516959460392577, max_iter=32,
#               n_iter_no_change=32, random_state=1, verbose=0, warm_start=True)}, 164: {'model_id': 164, 'rank': 5, 'cost': 0.19387755102040816, 'ensemble_weight': 0.12, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x41706a20a0>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x41c9284e80>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x41c9284be0>, 'sklearn_classifier': MLPClassifier(alpha=0.004559251361991539, beta_1=0.999, beta_2=0.9,
#               hidden_layer_sizes=(134,),
#               learning_rate_init=0.0002649035209926088, max_iter=256,
#               n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#               verbose=0, warm_start=True)}, 178: {'model_id': 178, 'rank': 6, 'cost': 0.19387755102040816, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x41703607f0>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x41f40ad670>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x41f40ad970>, 'sklearn_classifier': LinearSVC(C=8401.827921633001, dual=False, intercept_scaling=1.0,
#           random_state=1, tol=0.010262787674309246)}, 181: {'model_id': 181, 'rank': 7, 'cost': 0.18367346938775508, 'ensemble_weight': 0.02, 'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x415f0b6370>, 'balancing': Balancing(random_state=1), 'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x415f07d4f0>, 'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x4133421a00>, 'sklearn_classifier': MLPClassifier(activation='tanh', alpha=2.022328452581057e-07, beta_1=0.999,
#               beta_2=0.9, hidden_layer_sizes=(35,),
#               learning_rate_init=0.1029067979794692, max_iter=64,
#               n_iter_no_change=32, random_state=1, validation_fraction=0.0,
#               verbose=0, warm_start=True)}}

# %%
y_hat = automl.predict(X_test)
print("Accuracy score", sklearn.metrics.accuracy_score(y_test, y_hat))
# Out:
# Accuracy score 0.8181818181818182

# %% [markdown]
# ## Exporting the model

# %%
import joblib
joblib.dump(automl, 'app/handlers/model.pkl')
# Out:
# ['app/handlers/model.pkl']
